# %%
from tkinter import Tk, Label, Entry, Button
from datetime import datetime

def get_dates():
    dates = []
    for entry in date_entries:
        date_string = entry.get()
        try:
            date = datetime.strptime(date_string, "%d/%m/%Y")
            translated_date = date.strftime("%Y-%m-%d")
            dates.append(translated_date)
        except ValueError:
            print("Invalid date format. Please use the DD/MM/YYYY format.")
            return
    print("Dates:", dates), dates
    # You can perform further analysis or store the dates as needed

# Create the main window
window = Tk()
window.title("Input Treatment Session Dates")

# Create date input labels and entry fields
date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date (DD/MM/YYYY):")
    label.pack()
    date_labels.append(label)

    entry = Entry(window)
    entry.pack()
    date_entries.append(entry)

# Create a button to retrieve the dates
button = Button(window, text="Analyze", command=get_dates)
button.pack()

# Start the GUI event loop
window.mainloop()
# Out:
# Dates: ['2023-06-04', '2023-06-11', '2023-06-18', '2023-06-25', '2023-07-02']

# %%
from tkinter import Tk, Label, Entry, Button
from datetime import datetime

def get_dates():
    dates = []
    for entry in date_entries:
        date_string = entry.get()
        try:
            date = datetime.strptime(date_string, "%d/%m/%Y")
            translated_date = date.strftime("%Y-%m-%d")
            dates.append(translated_date)
        except ValueError:
            print("Invalid date format. Please use the DD/MM/YYYY format.")
            return []

    # Verify the order of dates
    for i in range(len(dates) - 1):
        if dates[i] >= dates[i + 1]:
            print("Dates are not in the correct order.")
            return []

    return dates

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x300")  # Set the size of the window

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date (DD/MM/YYYY):")
    label.pack()
    date_labels.append(label)

    entry = Entry(window)
    entry.pack()
    date_entries.append(entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

# Start the GUI event loop
window.mainloop()

# %%
from tkinter import Tk, Label, Entry, Button, filedialog
from datetime import datetime

def get_dates():
    dates = []
    for entry in date_entries:
        date_string = entry.get()
        try:
            date = datetime.strptime(date_string, "%d/%m/%Y")
            translated_date = date.strftime("%Y-%m-%d")
            dates.append(translated_date)
        except ValueError:
            print("Invalid date format. Please use the DD/MM/YYYY format.")
            return []

    # Verify the order of dates
    for i in range(len(dates) - 1):
        if dates[i] >= dates[i + 1]:
            print("Dates are not in the correct order.")
            return []

    return dates

def select_file():
    file_path = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if file_path:
        # Run your analyzing code using the selected file
        print("Analyzing file:", file_path)
        # Add your analyzing code here

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x350")  # Set the size of the window

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date (DD/MM/YYYY):")
    label.pack()
    date_labels.append(label)

    entry = Entry(window)
    entry.pack()
    date_entries.append(entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

# Start the GUI event loop
window.mainloop()

# %%
from tkinter import Tk, Label, Entry, Button, filedialog
from datetime import datetime

def get_dates():
    dates = []
    for entry in date_entries:
        date_string = entry.get()
        try:
            date = datetime.strptime(date_string, "%d/%m/%Y")
            translated_date = date.strftime("%Y-%m-%d")
            dates.append(translated_date)
        except ValueError:
            print("Invalid date format. Please use the DD/MM/YYYY format.")
            return []

    # Verify the order of dates
    for i in range(len(dates) - 1):
        if dates[i] >= dates[i + 1]:
            print("Dates are not in the correct order.")
            return []

    return dates

def select_file():
    file_path = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if file_path:
        # Run your analyzing code using the selected file
        print("Analyzing file:", file_path)
        # Add your analyzing code here

        # Close the GUI window
        window.destroy()

def on_closing():
    # Handle the window closing event
    print("Closing the window...")
    # Add any necessary cleanup or additional logic here

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x350")  # Set the size of the window

# Bind the window closing event to the on_closing function
window.protocol("WM_DELETE_WINDOW", on_closing)

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date (DD/MM/YYYY):")
    label.pack()
    date_labels.append(label)

    entry = Entry(window)
    entry.pack()
    date_entries.append(entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

# Start the GUI event loop
window.mainloop()
# Out:
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Closing the window...
# Analyzing file: C:/Users/yoavm/Downloads/leads.csv

# %%
from tkinter import Tk, Label, Entry, Button, filedialog
from datetime import datetime

def get_dates():
    dates = []
    for entry in date_entries:
        date_string = entry.get()
        try:
            date = datetime.strptime(date_string, "%d/%m/%Y")
            translated_date = date.strftime("%Y-%m-%d")
            dates.append(translated_date)
        except ValueError:
            print("Invalid date format. Please use the DD/MM/YYYY format.")
            return []

    # Verify the order of dates
    for i in range(len(dates) - 1):
        if dates[i] >= dates[i + 1]:
            print("Dates are not in the correct order.")
            return []

    return dates

def select_file():
    file_path = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if file_path:
        # Run your analyzing code using the selected file
        print("Analyzing file:", file_path)
        # Add your analyzing code here

def on_closing():
    # Handle the window closing event
    print("Closing the window...")
    window.destroy()

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x350")  # Set the size of the window

# Bind the window closing event to the on_closing function
window.protocol("WM_DELETE_WINDOW", on_closing)

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date (DD/MM/YYYY):")
    label.pack()
    date_labels.append(label)

    entry = Entry(window)
    entry.pack()
    date_entries.append(entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

# Start the GUI event loop
window.mainloop()
# Out:
# Closing the window...

# %%
from tkinter import Tk, Label, Button
from tkcalendar import DateEntry

def get_dates():
    dates = []
    for date_entry in date_entries:
        date = date_entry.get_date()
        dates.append(date.strftime("%Y-%m-%d"))
    return dates

def select_file():
    # Add your code for file selection and analysis here
    pass

def on_closing():
    window.destroy()

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x350")

# Bind the window closing event to the on_closing function
window.protocol("WM_DELETE_WINDOW", on_closing)

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date:")
    label.pack()
    date_labels.append(label)

    date_entry = DateEntry(window, date_pattern="dd/mm/yyyy")
    date_entry.pack()
    date_entries.append(date_entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

# Start the GUI event loop
window.mainloop()

# %%
from tkinter import Tk, Label, Button, filedialog
from tkcalendar import DateEntry

def get_dates():
    dates = []
    for date_entry in date_entries:
        date = date_entry.get_date()
        dates.append(date.strftime("%Y-%m-%d"))
    return dates

def select_file():
    file_path = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if file_path:
        # Run your analyzing code using the selected file
        print("Analyzing file:", file_path)
        # Add your analyzing code here

def on_closing():
    window.destroy()

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x400")

# Bind the window closing event to the on_closing function
window.protocol("WM_DELETE_WINDOW", on_closing)

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date:")
    label.pack()
    date_labels.append(label)

    date_entry = DateEntry(window, date_pattern="dd/mm/yyyy")
    date_entry.pack()
    date_entries.append(date_entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

# Start the GUI event loop
window.mainloop()
# Out:
# Analyzing file: C:/Users/yoavm/Downloads/Intrusions+Diary+-+Daily+summery_25+October+2022_15.23.csv

# %%
from tkinter import Tk, Label, Button, filedialog
from tkcalendar import DateEntry

def get_dates():
    dates = []
    for date_entry in date_entries:
        date = date_entry.get_date()
        dates.append(date.strftime("%Y-%m-%d"))
    return dates

def select_file():
    file_path = filedialog.askopenfilename()
    if file_path:
        # Run your analyzing code using the selected file
        print("Analyzing file:", file_path)
        # Add your analyzing code here

def on_closing():
    window.destroy()

# Create the main window
window = Tk()
window.title("Date Input")
window.geometry("400x400")

# Bind the window closing event to the on_closing function
window.protocol("WM_DELETE_WINDOW", on_closing)

date_labels = []
date_entries = []
for i in range(1, 6):
    label = Label(window, text=f"Treatment session {i} date:")
    label.pack()
    date_labels.append(label)

    date_entry = DateEntry(window, date_pattern="dd/mm/yyyy")
    date_entry.pack()
    date_entries.append(date_entry)

button = Button(window, text="Get Dates", command=lambda: print("Dates:", get_dates()))
button.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

# Start the GUI event loop
window.mainloop()
# Out:
# Analyzing file: C:/Users/yoavm/Downloads/Intrusions+Diary+-+Daily+summery_26+June+2023_15.17 (1).xlsx
# Dates: ['2023-06-04', '2023-06-11', '2023-06-18', '2023-06-25', '2023-07-02']

# %%
from tkinter import Tk, Label, Button, filedialog
from tkcalendar import DateEntry

def get_dates():
    dates = []
    for date_entry in date_entries:
        date = date_entry.get_date()
        dates.append(date.strftime("%Y-%m-%d"))
    window.destroy()  # Close the window after retrieving dates
    return dates

def select_file():
    file_path = filedialog.askopenfilename()
    if file_path:
        window.withdraw()  # Hide the current window
        create_date_selection_window()

def create_date_selection_window():
    global window, date_labels, date_entries
    window = Tk()
    window.title("Date Input")
    window.geometry("400x400")

    date_labels = []
    date_entries = []
    for i in range(1, 6):
        label = Label(window, text=f"Treatment session {i} date:")
        label.pack()
        date_labels.append(label)

        date_entry = DateEntry(window, date_pattern="dd/mm/yyyy")
        date_entry.pack()
        date_entries.append(date_entry)

    button = Button(window, text="Analyze", command=lambda: print("Dates:", get_dates()))
    button.pack()

    window.mainloop()

# Create the main window for file selection
window = Tk()
window.title("File Selection")
window.geometry("400x100")

file_label = Label(window, text="Select a file:")
file_label.pack()

file_button = Button(window, text="Select File", command=select_file)
file_button.pack()

window.mainloop()
# Out:
# Dates: ['2023-06-04', '2023-06-11', '2023-06-18', '2023-06-25', '2023-07-02']
